# %% [markdown]
# # Research back propagation
#
# and derivative

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
# %matplotlib inline

# %%
def sigmoid(z):
    f = 1 / (1 + np.exp(-z))
    return f

# %%
x = np.arange(-2,2,0.1)
w = 0.5

# %%
plt.plot(x, sigmoid(0.1*x))
plt.plot(x, sigmoid(0.5*x))
plt.plot(x, sigmoid(5*x))
plt.grid(1)

# %%
def sigmoid_prime(x):
    ds = np.exp(-x)/((1+np.exp(-x))**2)
    return ds

# %%
x = np.arange(-5,5,0.1)
labels=[]
for w in np.arange(0, 1.1, 0.25):
    plt.plot(x, sigmoid(x*w))
    labels.append("sigm w="+str(w))
    plt.plot(x, sigmoid_prime(x*w)*x)
    labels.append("sigm_pr w="+str(w))
    
plt.grid(1)
plt.legend(labels, loc='upper left',bbox_to_anchor=(1,1))
